# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/titanic.csv')

# %%
len(df)
# Out:
# 891

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df['Age'] > 20
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'] > 20]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Age_index"] = df['Age'] * df['Fare']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_index
# 0      0         A/5 21171   7.2500   NaN        S   159.5000
# 1      0          PC 17599  71.2833   C85        C  2708.7654
# 2      0  STON/O2. 3101282   7.9250   NaN        S   206.0500
# 3      0            113803  53.1000  C123        S  1858.5000
# ...

# %%
def mark_sex(sex: str) -> int:
    if sex == 'female':
        return 0
    return 1

df['Sex_bool'] = df['Sex'].apply(mark_sex)

# %%
df['Sex_bool'] = df['Sex'].apply(mark_sex)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_index  Sex_bool
# 0      0         A/5 21171   7.2500   NaN        S   159.5000         1
# 1      0          PC 17599  71.2833   C85        C  2708.7654         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S   206.0500         0
# ...

# %%
df2 = df[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Age_index', 'Sex_bool']].dropna()

# %%
df2.corr()
# Out:
#            Survived    Pclass       Age     SibSp     Parch      Fare  \
# Survived   1.000000 -0.359653 -0.077221 -0.017358  0.093317  0.268189
# Pclass    -0.359653  1.000000 -0.369226  0.067247  0.025683 -0.554182
# Age       -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp     -0.017358  0.067247 -0.308247  1.000000  0.383820  0.138329
# Parch      0.093317  0.025683 -0.189119  0.383820  1.000000  0.205119
# Fare       0.268189 -0.554182  0.096067  0.138329  0.205119  1.000000
# Age_index  0.227573 -0.564098  0.360269  0.023346  0.126489  0.907404
# Sex_bool  -0.538826  0.155460  0.093254 -0.103950 -0.246972 -0.184994
#
#            Age_index  Sex_bool
# Survived    0.227573 -0.538826
# Pclass     -0.564098  0.155460
# Age         0.360269  0.093254
# SibSp       0.023346 -0.103950
# Parch       0.126489 -0.246972
# Fare        0.907404 -0.184994
# Age_index   1.000000 -0.144961
# Sex_bool   -0.144961  1.000000

# %%
df3 = df.dropna()

# %%
df3.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Age_index  Sex_bool
# 1       0  PC 17599  71.2833   C85        C  2708.7654         0
# 3       0    113803  53.1000  C123        S  1858.5000         0
# 6       0     17463  51.8625   E46        S  2800.5750         1
# ...

# %%
def mark_sex(sex: str) -> int:
    if sex == 'female':
        return 0
    return 1

df['Sex_bool'] = df['Sex'].apply(mark_sex)

# %%
def extract_letter(cabin):
    cabin_letter = cabin[0]
    return cabin_letter

df3['Ship_part'] = df3['Cabin'].apply(extract_letter)
# Out:
# /var/folders/d2/vsm7h4rj16d99xx8g575jk1m0000gn/T/ipykernel_60022/1053461259.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Ship_part'] = df3['Cabin'].apply(extract_letter)

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def extract_number(cabin):
    x = cabin
    if ' ' in cabin:
        i = cabin.find(" ")
        cabin = cabin[:i]

    cabin_letter = cabin[1:]
    if len(cabin_letter):
        return int(cabin_letter)
    print(x, cabin_letter)

df3['room_number'] = df3['Cabin'].apply(extract_number)
# Out:
# F G73
# D
# D
# T
# D
# F G63
# F G73
# /var/folders/d2/vsm7h4rj16d99xx8g575jk1m0000gn/T/ipykernel_60022/3913297350.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['room_number'] = df3['Cabin'].apply(extract_number)

# %%
df4 = df3.dropna()

# %%
df4.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Age_index  Sex_bool Ship_part  \
# 1       0  PC 17599  71.2833   C85        C  2708.7654         0         C
# 3       0    113803  53.1000  C123        S  1858.5000         0         C
# 6       0     17463  51.8625   E46        S  2800.5750         1         E
# ...

# %%
mas = list(df4['Ship_part'].unique())
# Out:
# ['C', 'E', 'G', 'D', 'A', 'B', 'F']

# %%
mas = list(df4['Ship_part'].unique())
indexes = list(range(len(mas)))

mapping = dict(zip(mas, indexes))

def encoder(ship_part):
    return mapping[ship_part]

df4['ship_part_encoded'] = df4['Ship_part'].apply(encoder)
# Out:
# /var/folders/d2/vsm7h4rj16d99xx8g575jk1m0000gn/T/ipykernel_60022/2871526201.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['ship_part_encoded'] = df4['Ship_part'].apply(encoder)

# %%
df4.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Age_index  Sex_bool Ship_part  \
# 1       0  PC 17599  71.2833   C85        C  2708.7654         0         C
# 3       0    113803  53.1000  C123        S  1858.5000         0         C
# 6       0     17463  51.8625   E46        S  2800.5750         1         E
# ...

# %%
len(df4)
# Out:
# 176

# %%
df4[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Age_index', 'Sex_bool', 'room_number', 'ship_part_encoded']].corr()
# Out:
#                    Survived    Pclass       Age     SibSp     Parch      Fare  \
# Survived           1.000000  0.057469 -0.267510  0.086282  0.003019  0.111761
# Pclass             0.057469  1.000000 -0.316871 -0.049445  0.117699 -0.278739
# Age               -0.267510 -0.316871  1.000000 -0.165396 -0.281115 -0.103620
# SibSp              0.086282 -0.049445 -0.165396  1.000000  0.241609  0.268734
# Parch              0.003019  0.117699 -0.281115  0.241609  1.000000  0.376911
# Fare               0.111761 -0.278739 -0.103620  0.268734  0.376911  1.000000
# Age_index          0.028999 -0.289755  0.310981  0.125035  0.255368  0.851519
# Sex_bool          -0.511911 -0.107717  0.189439 -0.095848 -0.081953 -0.121461
# room_number       -0.043545 -0.092916  0.079586 -0.060205 -0.091195  0.082890
# ship_part_encoded  0.123490  0.071305 -0.098828 -0.133080  0.049251 -0.007713
#
#                    Age_index  Sex_bool  room_number  ship_part_encoded
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.7.5-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.7 kB)
# ...
#   Using cached contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (5.9 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.57.0-cp38-cp38-macosx_10_9_universal2.whl.metadata (102 kB)
# ...
#   Using cached kiwisolver-1.4.7-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-10.4.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (9.2 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached matplotlib-3.7.5-cp38-cp38-macosx_11_0_arm64.whl (7.3 MB)
# Using cached contourpy-1.1.1-cp38-cp38-macosx_11_0_arm64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.57.0-cp38-cp38-macosx_10_9_universal2.whl (2.8 MB)
# Using cached kiwisolver-1.4.7-cp38-cp38-macosx_11_0_arm64.whl (64 kB)
# Using cached pillow-10.4.0-cp38-cp38-macosx_11_0_arm64.whl (3.4 MB)
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df4['Age'], df4['Fare'])

# %%
plt.scatter(df4['Age'], df4['Fare'])

# %%
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.pie(df4['Sex_bool'])
# Out:
# ([<matplotlib.patches.Wedge at 0x12ff6b760>,
# ...
#  [Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.0993299096885571, 0.0383894473019504, ''),
#   Text(1.0973204551560924, 0.07673212297353954, ''),
#   Text(1.0973204551560924, 0.07673212297353954, ''),
#   Text(1.09397408461354, 0.1149813123684359, ''),
#   Text(1.0832885275061683, 0.1910130000118258, ''),
#   Text(1.0673252973290814, 0.26611409147466836, ''),
#   Text(1.0573878634819256, 0.30320109854868443, ''),
#   Text(1.0461621653388484, 0.3399187017707798, ''),
#   Text(1.019902236192206, 0.4120672622402046, ''),
#   Text(1.0048999988688236, 0.44741031757597916, ''),
#   Text(1.0048999988688236, 0.44741031757597916, ''),
#   Text(0.9886734456305116, 0.4822082723316677, ''),
#   Text(0.9526279371896396, 0.5500000120780109, ''),
#   Text(0.9119413209719333, 0.6151122069216036, ''),
#   Text(0.8668118180913964, 0.6772276367788662, ''),
#   Text(0.8174592949603051, 0.7360436815047061, ''),
# ...

# %%
plt.hist(df4['Age'])
# Out:
# (array([10.,  6., 30., 29., 38., 22., 23., 13.,  4.,  1.]),
#  array([ 0.92 ,  8.828, 16.736, 24.644, 32.552, 40.46 , 48.368, 56.276,
#         64.184, 72.092, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
# !pip install psycopg2-binary SQLAlchemy
# Out:
# ...
#   Using cached psycopg2-binary-2.9.10.tar.gz (385 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.2 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for psycopg2-binary: filename=psycopg2_binary-2.9.10-cp38-cp38-macosx_10_14_arm64.whl size=243269 sha256=9a91da725e190f9bfe5017cb738d0c500002bd93a000892071bb228f089c989a
#   Stored in directory: /Users/mac/Library/Caches/pip/wheels/df/fb/7d/c43b1faf8e1ae26e14d1e183eca11ef5560125067a34948080
# Successfully built psycopg2-binary
# ...

# %%
import pandas as pd
import psycopg2 as pg

engine = pg.connect("dbname='my_db_name' user='pguser' host='127.0.0.1' port='15432' password='pgpassword'")
df = pd.read_sql('select * from Stat_Table', con=engine)

# %%
from PSQL_connector import PSQLConnector

# %%
with PSQLConnector(**DB_CONFIG) as connector:
    df = connector.execute_query(
        "Select * from di.dm_receiptitems limit 100000"
    )
# Out:
# Successfully connected to PostgreSQL database
# /Users/mac/Desktop/Anggell_python/PSQL_connector.py:62: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, self.connection)
# PostgreSQL connection closed

# %%
df.head()
# Out:
#   restaurant_id    table_id table_name  \
# 0       01_Test   01_Test/3          3
# 1       01_Test   01_Test/3          3
# 2       01_Test   01_Test/3          3
# 3       01_Test   01_Test/3          3
# 4       01_Test  01_Test/28         28
#
#                                      receipt_id   receipt_open_time  \
# 0  01_Test/042106a6-f073-42a3-be3a-e77535ddcaac 2024-10-10 19:10:34
# 1  01_Test/042106a6-f073-42a3-be3a-e77535ddcaac 2024-10-10 19:10:34
# 2  01_Test/042106a6-f073-42a3-be3a-e77535ddcaac 2024-10-10 19:10:34
# 3  01_Test/042106a6-f073-42a3-be3a-e77535ddcaac 2024-10-10 19:10:34
# 4  01_Test/043bc907-3e2b-4f83-9743-c6bed6538463 2024-10-10 19:12:09
#
#    receipt_close_time                             item_b_id  \
# 0 2024-10-10 20:51:56  ceac3265-dfe5-4bda-b037-b4d33743bc70
# 1 2024-10-10 20:51:56  a33feaa8-6c53-4f77-96ac-4d85edca2828
# 2 2024-10-10 20:51:56  3bd457a4-fb86-4596-856c-704841f73549
# 3 2024-10-10 20:51:56  303c7b4e-49d6-4d64-88e2-e94b02156a0e
# ...

# %%
df.columns
# Out:
# Index(['restaurant_id', 'table_id', 'table_name', 'receipt_id',
#        'receipt_open_time', 'receipt_close_time', 'item_b_id', 'item_id',
#        'dish_b_id', 'dish_id', 'dish_name', 'category_b_lvl1_name',
#        'category_b_lvl2_name', 'category_b_lvl3_name', 'category_b_lvl4_name',
#        'category_b_lvl5_name', 'category_b_lvl6_name', 'category_b_lvl7_name',
#        'category_b_lvl8_name', 'category_b_lvl9_name', 'category_b_lvl10_name',
#        'item_quantity', 'item_price', 'item_total_price', 'item_costprice',
#        'discount_sum', 'item_discount_cost', 'check_receipt_total',
#        'item_currency', 'item_is_deleted', 'item_is_included',
#        'item_is_deleted_comment', 'item_order_time', 'waiter_order_id',
#        'waiter_invoice_id', 'meal', 'weekend', 'item_tax_amount',
#        'item_tax_rate', 'tags', 'receipt_open_time_offset',
#        'receipt_close_time_offset', 'item_order_time_offset', 'rec_date',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   restaurant_id                   100000 non-null  object
#  1   table_id                        75133 non-null   object
#  2   table_name                      75133 non-null   object
#  3   receipt_id                      100000 non-null  object
#  4   receipt_open_time               100000 non-null  datetime64[ns]
#  5   receipt_close_time              100000 non-null  datetime64[ns]
#  6   item_b_id                       100000 non-null  object
#  7   item_id                         100000 non-null  object
#  8   dish_b_id                       100000 non-null  object
#  9   dish_id                         100000 non-null  object
#  10  dish_name                       100000 non-null  object
# ...

# %%
df2 = df.sort_values(by='receipt_open_time')

# %%
import datetime

# %%
df3 = df2[(df2['receipt_open_time'] < datetime.datetime(year=2025, month=1, day=1)) & (df2['receipt_open_time'] > datetime.datetime(year=2024, month=7, day=1))]

# %%
plt.figure(figsize=(20, 10))

plt.plot(df3['receipt_open_time'], df3['check_receipt_total'])

# %%
df3['open_date'] = df3['receipt_open_time'].dt.date
# Out:
# /var/folders/d2/vsm7h4rj16d99xx8g575jk1m0000gn/T/ipykernel_60022/2432013336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['open_date'] = df3['receipt_open_time'].dt.date

# %%
df4 = df3.groupby('open_date')['check_receipt_total'].median()

# %%
df5 = df4.reset_index()

# %%
plt.figure(figsize=(20, 10))

plt.plot(df5['open_date'], df5['check_receipt_total'])

# %%
plt.figure(figsize=(20, 10))

plt.plot(df5['open_date'], df5['check_receipt_total'])
